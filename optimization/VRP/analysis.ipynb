# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('results/results.csv', sep=';')
df.head()
# Out:
#     type  nr_of_clients  optimal_cost terminal_condition  duration_seconds
# 0  pyomo              5        710.33            optimal              0.05
# 1     sa              5        710.33               none             31.06
# 2  pyomo             10       1026.88            optimal              1.55
# 3     sa             10       1026.88               none             47.68
# 4  pyomo             15       1440.93            optimal            183.11

# %%
# Plot
plt.figure(figsize=(8, 5))
sns.barplot(x='nr_of_clients', y='optimal_cost', hue='type', data=df, palette='viridis')

# Labels and title
plt.xlabel('Type')
plt.ylabel('Optimal Cost')
plt.title('Optimal Cost by Type and Number of Clients')
plt.legend(title="Number of Clients")

# Show the plot
plt.show()

# %%
# Plot
plt.figure(figsize=(8, 5))
sns.barplot(x='nr_of_clients', y='duration_seconds', hue='type', data=df, palette='viridis')

# Labels and title
plt.xlabel('Type')
plt.ylabel('Duration (s)')
plt.title('Duration by Type and Number of Clients')
plt.legend(title="Number of Clients")

# Show the plot
plt.show()
